# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### Assignment 2

# %% [markdown]
# #### 1.Distance, JobRole and Attrition Breakdown

# %%
df_home=df.loc[:,['DistanceFromHome','JobRole','Attrition']]

# %%
#Jobrole and Distance by Total Attrition Counts
df_home.groupby(['JobRole','DistanceFromHome'])['Attrition'].count().sort_values(ascending=False)
# Out:
# JobRole                 DistanceFromHome
# Research Scientist      1                   47
# Sales Executive         2                   39
#                         1                   39
# Laboratory Technician   2                   36
# Research Scientist      2                   36
#                                             ..
# Manufacturing Director  15                   1
# Sales Representative    28                   1
# Human Resources         5                    1
# Laboratory Technician   22                   1
# Sales Representative    29                   1
# Name: Attrition, Length: 224, dtype: int64

# %%
#Jobrole and Distance by Breakdown of Attrition Counts
df2=df_home.query('Attrition=="Yes"').groupby(['JobRole','DistanceFromHome'])['Attrition'].count().sort_values(ascending=False)
df2
# Out:
# JobRole                    DistanceFromHome
# Laboratory Technician      2                   11
# Research Scientist         1                    7
# Sales Representative       1                    7
# Sales Executive            1                    6
# Sales Representative       9                    6
#                                                ..
# Laboratory Technician      21                   1
# Sales Executive            15                   1
#                            18                   1
# Research Scientist         14                   1
# Healthcare Representative  2                    1
# Name: Attrition, Length: 112, dtype: int64

# %%
#Contingency Table For Jobroles with Breakdown on Attrition 
jroles=pd.crosstab(df.JobRole,df.Attrition).sort_values(by='Yes',axis=0,ascending=False)
jroles
# Out:
# Attrition                   No  Yes
# JobRole
# Laboratory Technician      197   62
# Sales Executive            269   57
# Research Scientist         245   47
# Sales Representative        50   33
# Human Resources             40   12
# Manufacturing Director     135   10
# Healthcare Representative  122    9
# Manager                     97    5
# Research Director           78    2

# %%
#Contingency Table For Jobroles and Distance showing Breakdown on Attrition 
df_distance=pd.crosstab([df.JobRole,df.DistanceFromHome],df.Attrition).sort_values(by='Yes',axis=0,ascending=False)
df_distance
# Out:
# Attrition                                No  Yes
# JobRole                DistanceFromHome
# Laboratory Technician  2                 25   11
# Sales Representative   1                  2    7
# Research Scientist     1                 40    7
# Sales Executive        1                 33    6
# Laboratory Technician  7                 10    6
# ...                                      ..  ...
# Manufacturing Director 11                 3    0
#                        12                 3    0
#                        13                 1    0
#                        15                 1    0
# Sales Representative   29                 1    0
#
# [224 rows x 2 columns]

# %%
pd.crosstab(df.DistanceFromHome,df.Attrition).sort_index(axis=0,ascending=True)
# Out:
# Attrition          No  Yes
# DistanceFromHome
# 1                 182   26
# 2                 183   28
# 3                  70   14
# 4                  55    9
# 5                  55   10
# 6                  52    7
# 7                  73   11
# 8                  70   10
# 9                  67   18
# 10                 75   11
# 11                 25    4
# 12                 14    6
# 13                 13    6
# 14                 17    4
# 15                 21    5
# 16                 25    7
# 17                 15    5
# 18                 22    4
# 19                 19    3
# 20                 21    4
# 21                 15    3
# 22                 13    6
# 23                 22    5
# 24                 16   12
# 25                 19    6
# 26                 22    3
# 27                  9    3
# 28                 21    2
# 29                 22    5

# %% [markdown]
# #### 2. Education and Monthly Income Analysis

# %%
def edu_numtostr(number):
    if number==1:
        return 'Below College'
    elif number==2:
        return 'College'
    elif number==3:
        return 'Bachelor'
    elif number==4:
        return 'Masters'
    elif number==5:
        return 'Doctorate'

# %%
#.map(edu_numtostr)

df['Education']=df['Education'].apply(edu_numtostr)

# %%
df_MonthIncome=df[['Education','MonthlyIncome','Attrition']]

# %%
df_MonthIncome.groupby(['Education'])['MonthlyIncome'].mean().sort_values(ascending=True)
# Out:
# Education
# Below College    5640.570588
# College          6226.645390
# Bachelor         6517.263986
# Masters          6832.402010
# Doctorate        8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
df_MonthIncome.groupby(['Attrition'])['MonthlyIncome'].mean().sort_values(ascending=True)
# Out:
# Attrition
# Yes    4787.092827
# No     6832.739659
# Name: MonthlyIncome, dtype: float64

# %%
df_aveIncome=df_MonthIncome.groupby(['Education','Attrition'],as_index=False)['MonthlyIncome'].mean().sort_values(by='Education',ascending=True)
#df_aveIncome.rename({'MonthlyIncome':'Average Income'},inplace=True)
df_aveIncome
# Out:
#        Education Attrition  MonthlyIncome
# 0       Bachelor        No    6882.919662
# 1       Bachelor       Yes    4770.242424
# 2  Below College        No    5926.129496
# 3  Below College       Yes    4360.161290
# 4        College        No    6586.058824
# 5        College       Yes    4282.545455
# 6      Doctorate        No    8559.906977
# 7      Doctorate       Yes    5850.200000
# 8        Masters        No    7087.814706
# 9        Masters       Yes    5335.155172

# %%
df_aveIncome.values
# Out:
# array([4282.54545455, 4360.16129032, 4770.24242424, 5335.15517241,
#        5850.2       , 5926.1294964 , 6586.05882353, 6882.91966173,
#        7087.81470588, 8559.90697674])

# %% [markdown]
# ### Assignment 3

# %%
pd.crosstab( df.JobRole,df.Attrition).plot.bar(stacked=False,ylabel='Frequency',title='JobRole Attrition' )
# Out:
# <AxesSubplot:title={'center':'JobRole Attrition'}, xlabel='JobRole', ylabel='Frequency'>

# %%
fig, ax = plt.subplots(figsize=(10, 8))
pd.crosstab(df.DistanceFromHome,df.Attrition).plot.bar(stacked=False, title='Distance & Attrition', ylabel='Frequency',xlabel='Distance From Home (km)',ax=ax)
# Out:
# <AxesSubplot:title={'center':'Distance & Attrition'}, xlabel='Distance From Home (km)', ylabel='Frequency'>

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_title( "Monthly Income By Education Category" , size = 14 )
sns.barplot( x='Education', y='MonthlyIncome',data=df_MonthIncome, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Monthly Income By Education Category'}, xlabel='Education', ylabel='MonthlyIncome'>

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_title( "Monthly Income By Attrition" , size = 14 )
sns.barplot( x='Attrition',y='MonthlyIncome', data=df_MonthIncome)
# Out:
# <AxesSubplot:title={'center':'Monthly Income By Attrition'}, xlabel='Attrition', ylabel='MonthlyIncome'>

# %%
fig, ax = plt.subplots(figsize=(3, 5))
ax.set_ylabel( "Monthly Income" , size = 10 )
ax.set_title( "Monthly Average Income" , size = 12 )
sns.boxplot(y=df_aveIncome)
# Out:
# <AxesSubplot:title={'center':'Monthly Average Income'}, ylabel='MonthlyIncome'>
